# %%
#Importing required python libraries

import pandas as pd
import numpy as np
import scipy.sparse as sparse
from scipy.sparse.linalg import spsolve
from sklearn.preprocessing import MinMaxScaler

books_df = pd.read_csv('/home/Sharvani/Documents/Books.csv',engine='python',sep=',')
books_df = books_df.rename(columns = {'ISBN;"Book-Title";"Book-Author";"Year-Of-Publication";"Publisher";"Image-URL-S";"Image-URL-M";"Image-URL-L"':'ISBN'})
books_df['book_title'] = books_df['ISBN'].str.split(';').str[1]
books_df['ISBN'] = books_df['ISBN'].str.split(';').str[0]
new_books_df = books_df[['book_title','ISBN']].drop_duplicates()
ratings_df = pd.read_csv("/home/Sharvani/Documents/CS512/Book-Ratings.csv", error_bad_lines=False)

merged_books_df = pd.merge(ratings_df,new_books_df,on='ISBN')
merged_books_df['ISBN_id'] = merged_books_df['ISBN'].astype("category").cat.codes
merged_books_df['USER_id'] = merged_books_df['User-ID'].astype("category").cat.codes

books_lookup = merged_books_df[['ISBN_id','book_title']].drop_duplicates()
books_lookup['ISBN_id'] = books_lookup.ISBN_id.astype(str)

merged_books_df.columns = ['User_ID','ISBN','Book_Rating','Book_Title','ISBN_ID','USER_id']

#full_data_books is a dataframe having complete information about book name, ID, userID.  
full_data_books = merged_books_df.copy()


merged_books_df = merged_books_df.drop(['User_ID','ISBN','Book_Title'],axis=1)
input_data_for_matrix = merged_books_df.loc[merged_books_df.Book_Rating != 0]

users = list(np.sort(input_data_for_matrix['USER_id'].unique()))
ISBN = list(np.sort(input_data_for_matrix['ISBN_ID'].unique()))
rating = list(input_data_for_matrix['Book_Rating'])
rows = input_data_for_matrix['USER_id'].astype(int)
cols = input_data_for_matrix['ISBN_ID'].astype(int)

ratings_matrix=sparse.csr_matrix((rating,(rows,cols)),shape = (len(rows),len(cols)))

# %%
#Details of the generated ratings sparse matrix 

print(ratings_matrix.data)
print(ratings_matrix.nnz)
# Out:
# [ 5.  5.  6. ... 10.  7.  7.]
# 73771

# %%
# ALS function generates 2 vectors X and Y. one for User_features and the other for items_features

def ALS(ratings_matrix,alpha,iterations,lambda_val,features):
    confidence_matrix = ratings_matrix * alpha
    
    user_size,book_size = ratings_matrix.shape
    print(user_size)
    print(book_size)
    X = sparse.csr_matrix(np.random.normal(size = (user_size,features)))
    Y = sparse.csr_matrix(np.random.normal(size = (book_size,features)))
    
    X_I = sparse.eye(user_size)
    Y_I = sparse.eye(book_size)
    
    I = sparse.eye(features)
    lI = lambda_val * I
    u_iteration = 0
    i_iteration = 0
    for i in range(iterations):
        #Update the two vectors X and Y which are respectively for users and books for 'iteration' number of iterations.
        print ('itearation %d of total %d iterations' % (i+1,iterations))
        
        yTy = Y.T.dot(Y)
        xTx = X.T.dot(X)
        
        for u in range(user_size):
            u_iteration += 1
            print('In U for the %d time' % (u_iteration))
            u_row = confidence_matrix[u,:].toarray() 

            p_u = u_row.copy()
            p_u[p_u != 0] = 1.0

            CuI = sparse.diags(u_row, [0])
            Cu = CuI + Y_I

            yT_CuI_y = Y.T.dot(CuI).dot(Y)
            yT_Cu_pu = Y.T.dot(Cu).dot(p_u.T)
            X[u] = spsolve(yTy + yT_CuI_y + lI, yT_Cu_pu)
            #This is one row updation of of the user vectors

    
        for i in range(book_size):
            i_iteration += 1
            print('In I for the %d time' % (i_iteration))
            i_row = confidence_matrix[:,i].T.toarray()

            p_i = i_row.copy()
            p_i[p_i != 0] = 1.0

            CiI = sparse.diags(i_row, [0])
            Ci = CiI + X_I

            xT_CiI_x = X.T.dot(CiI).dot(X)
            xT_Ci_pi = X.T.dot(Ci).dot(p_i.T)
            Y[i] = spsolve(xTx + xT_CiI_x + lI, xT_Ci_pi)
            #This is one column updation of of the book vectors
    print('Vectores X and Y have been created')
    return X, Y
    #in the end, we return the two vectors X and Y based on which recommendations are to be done

# %%
X,Y = ALS(ratings_matrix,40,1,0.1,10)
# Out:
# 73771
# 73771
# itearation 1 of total 1 iterations
# In U for the 1 time
# In U for the 2 time
# In U for the 3 time
# In U for the 4 time
# In U for the 5 time
# In U for the 6 time
# In U for the 7 time
# In U for the 8 time
# In U for the 9 time
# In U for the 10 time
# In U for the 11 time
# In U for the 12 time
# In U for the 13 time
# In U for the 14 time
# In U for the 15 time
# In U for the 16 time
# In U for the 17 time
# In U for the 18 time
# In U for the 19 time
# In U for the 20 time
# In U for the 21 time
# In U for the 22 time
# In U for the 23 time
# In U for the 24 time
# In U for the 25 time
# In U for the 26 time
# In U for the 27 time
# In U for the 28 time
# In U for the 29 time
# In U for the 30 time
# In U for the 31 time
# In U for the 32 time
# In U for the 33 time
# In U for the 34 time
# In U for the 35 time
# In U for the 36 time
# In U for the 37 time
# In U for the 38 time
# In U for the 39 time
# In U for the 40 time
# In U for the 41 time
# In U for the 42 time
# In U for the 43 time
# In U for the 44 time
# In U for the 45 time
# In U for the 46 time
# In U for the 47 time
# In U for the 48 time
# In U for the 49 time
# In U for the 50 time
# In U for the 51 time
# In U for the 52 time
# In U for the 53 time
# In U for the 54 time
# In U for the 55 time
# In U for the 56 time
# In U for the 57 time
# In U for the 58 time
# In U for the 59 time
# In U for the 60 time
# In U for the 61 time
# In U for the 62 time
# In U for the 63 time
# In U for the 64 time
# In U for the 65 time
# In U for the 66 time
# In U for the 67 time
# In U for the 68 time
# In U for the 69 time
# In U for the 70 time
# In U for the 71 time
# In U for the 72 time
# In U for the 73 time
# In U for the 74 time
# In U for the 75 time
# In U for the 76 time
# In U for the 77 time
# In U for the 78 time
# In U for the 79 time
# In U for the 80 time
# In U for the 81 time
# In U for the 82 time
# In U for the 83 time
# In U for the 84 time
# In U for the 85 time
# In U for the 86 time
# In U for the 87 time
# In U for the 88 time
# In U for the 89 time
# In U for the 90 time
# In U for the 91 time
# In U for the 92 time
# In U for the 93 time
# In U for the 94 time
# In U for the 95 time
# In U for the 96 time
# In U for the 97 time
# In U for the 98 time
# In U for the 99 time
# In U for the 100 time
# In U for the 101 time
# In U for the 102 time
# In U for the 103 time
# In U for the 104 time
# In U for the 105 time
# In U for the 106 time
# In U for the 107 time
# In U for the 108 time
# In U for the 109 time
# In U for the 110 time
# In U for the 111 time
# In U for the 112 time
# In U for the 113 time
# In U for the 114 time
# In U for the 115 time
# In U for the 116 time
# In U for the 117 time
# In U for the 118 time
# In U for the 119 time
# In U for the 120 time
# In U for the 121 time
# In U for the 122 time
# In U for the 123 time
# In U for the 124 time
# In U for the 125 time
# In U for the 126 time
# In U for the 127 time
# In U for the 128 time
# In U for the 129 time
# In U for the 130 time
# In U for the 131 time
# In U for the 132 time
# In U for the 133 time
# In U for the 134 time
# In U for the 135 time
# In U for the 136 time
# In U for the 137 time
# In U for the 138 time
# In U for the 139 time
# In U for the 140 time
# In U for the 141 time
# In U for the 142 time
# In U for the 143 time
# In U for the 144 time
# In U for the 145 time
# In U for the 146 time
# In U for the 147 time
# In U for the 148 time
# In U for the 149 time
# In U for the 150 time
# In U for the 151 time
# In U for the 152 time
# In U for the 153 time
# In U for the 154 time
# In U for the 155 time
# In U for the 156 time
# In U for the 157 time
# In U for the 158 time
# In U for the 159 time
# In U for the 160 time
# In U for the 161 time
# In U for the 162 time
# In U for the 163 time
# In U for the 164 time
# In U for the 165 time
# In U for the 166 time
# In U for the 167 time
# In U for the 168 time
# In U for the 169 time
# In U for the 170 time
# In U for the 171 time
# In U for the 172 time
# In U for the 173 time
# In U for the 174 time
# In U for the 175 time
# In U for the 176 time
# In U for the 177 time
# In U for the 178 time
# In U for the 179 time
# In U for the 180 time
# In U for the 181 time
# In U for the 182 time
# In U for the 183 time
# In U for the 184 time
# In U for the 185 time
# In U for the 186 time
# In U for the 187 time
# In U for the 188 time
# In U for the 189 time
# In U for the 190 time
# In U for the 191 time
# In U for the 192 time
# In U for the 193 time
# In U for the 194 time
# In U for the 195 time
# In U for the 196 time
# In U for the 197 time
# In U for the 198 time
# In U for the 199 time
# In U for the 200 time
# In U for the 201 time
# In U for the 202 time
# In U for the 203 time
# In U for the 204 time
# In U for the 205 time
# In U for the 206 time
# In U for the 207 time
# In U for the 208 time
# In U for the 209 time
# In U for the 210 time
# In U for the 211 time
# In U for the 212 time
# In U for the 213 time
# In U for the 214 time
# In U for the 215 time
# In U for the 216 time
# In U for the 217 time
# In U for the 218 time
# In U for the 219 time
# In U for the 220 time
# In U for the 221 time
# In U for the 222 time
# In U for the 223 time
# In U for the 224 time
# In U for the 225 time
# In U for the 226 time
# In U for the 227 time
# In U for the 228 time
# In U for the 229 time
# In U for the 230 time
# In U for the 231 time
# In U for the 232 time
# In U for the 233 time
# In U for the 234 time
# In U for the 235 time
# In U for the 236 time
# In U for the 237 time
# In U for the 238 time
# In U for the 239 time
# In U for the 240 time
# In U for the 241 time
# In U for the 242 time
# In U for the 243 time
# In U for the 244 time
# In U for the 245 time
# In U for the 246 time
# In U for the 247 time
# In U for the 248 time
# In U for the 249 time
# In U for the 250 time
# In U for the 251 time
# In U for the 252 time
# In U for the 253 time
# In U for the 254 time
# In U for the 255 time
# In U for the 256 time
# In U for the 257 time
# In U for the 258 time
# In U for the 259 time
# In U for the 260 time
# In U for the 261 time
# In U for the 262 time
# In U for the 263 time
# In U for the 264 time
# In U for the 265 time
# In U for the 266 time
# In U for the 267 time
# In U for the 268 time
# In U for the 269 time
# In U for the 270 time
# In U for the 271 time
# In U for the 272 time
# In U for the 273 time
# In U for the 274 time
# In U for the 275 time
# In U for the 276 time
# In U for the 277 time
# In U for the 278 time
# In U for the 279 time
# In U for the 280 time
# In U for the 281 time
# In U for the 282 time
# In U for the 283 time
# In U for the 284 time
# In U for the 285 time
# In U for the 286 time
# In U for the 287 time
# In U for the 288 time
# In U for the 289 time
# In U for the 290 time
# In U for the 291 time
# In U for the 292 time
# In U for the 293 time
# In U for the 294 time
# In U for the 295 time
# In U for the 296 time
# In U for the 297 time
# In U for the 298 time
# In U for the 299 time
# In U for the 300 time
# In U for the 301 time
# In U for the 302 time
# In U for the 303 time
# In U for the 304 time
# In U for the 305 time
# In U for the 306 time
# In U for the 307 time
# In U for the 308 time
# In U for the 309 time
# In U for the 310 time
# In U for the 311 time
# In U for the 312 time
# In U for the 313 time
# In U for the 314 time
# In U for the 315 time
# In U for the 316 time
# In U for the 317 time
# In U for the 318 time
# In U for the 319 time
# In U for the 320 time
# In U for the 321 time
# In U for the 322 time
# In U for the 323 time
# In U for the 324 time
# In U for the 325 time
# In U for the 326 time
# In U for the 327 time
# In U for the 328 time
# In U for the 329 time
# In U for the 330 time
# In U for the 331 time
# In U for the 332 time
# In U for the 333 time
# In U for the 334 time
# In U for the 335 time
# In U for the 336 time
# In U for the 337 time
# In U for the 338 time
# In U for the 339 time
# In U for the 340 time
# In U for the 341 time
# In U for the 342 time
# In U for the 343 time
# In U for the 344 time
# In U for the 345 time
# In U for the 346 time
# In U for the 347 time
# In U for the 348 time
# In U for the 349 time
# In U for the 350 time
# In U for the 351 time
# In U for the 352 time
# In U for the 353 time
# In U for the 354 time
# In U for the 355 time
# In U for the 356 time
# In U for the 357 time
# In U for the 358 time
# In U for the 359 time
# In U for the 360 time
# In U for the 361 time
# In U for the 362 time
# In U for the 363 time
# In U for the 364 time
# In U for the 365 time
# In U for the 366 time
# In U for the 367 time
# In U for the 368 time
# In U for the 369 time
# In U for the 370 time
# In U for the 371 time
# In U for the 372 time
# In U for the 373 time
# In U for the 374 time
# In U for the 375 time
# In U for the 376 time
# In U for the 377 time
# In U for the 378 time
# In U for the 379 time
# In U for the 380 time
# In U for the 381 time
# In U for the 382 time
# In U for the 383 time
# In U for the 384 time
# In U for the 385 time
# In U for the 386 time
# In U for the 387 time
# In U for the 388 time
# In U for the 389 time
# In U for the 390 time
# In U for the 391 time
# In U for the 392 time
# In U for the 393 time
# In U for the 394 time
# In U for the 395 time
# In U for the 396 time
# In U for the 397 time
# In U for the 398 time
# In U for the 399 time
# In U for the 400 time
# In U for the 401 time
# In U for the 402 time
# In U for the 403 time
# In U for the 404 time
# In U for the 405 time
# In U for the 406 time
# In U for the 407 time
# In U for the 408 time
# In U for the 409 time
# In U for the 410 time
# In U for the 411 time
# In U for the 412 time
# In U for the 413 time
# In U for the 414 time
# In U for the 415 time
# In U for the 416 time
# In U for the 417 time
# In U for the 418 time
# In U for the 419 time
# In U for the 420 time
# In U for the 421 time
# In U for the 422 time
# In U for the 423 time
# In U for the 424 time
# In U for the 425 time
# In U for the 426 time
# In U for the 427 time
# In U for the 428 time
# In U for the 429 time
# In U for the 430 time
# In U for the 431 time
# In U for the 432 time
# In U for the 433 time
# In U for the 434 time
# In U for the 435 time
# In U for the 436 time
# In U for the 437 time
# In U for the 438 time
# In U for the 439 time
# In U for the 440 time
# In U for the 441 time
# In U for the 442 time
# In U for the 443 time
# In U for the 444 time
# In U for the 445 time
# In U for the 446 time
# In U for the 447 time
# In U for the 448 time
# In U for the 449 time
# In U for the 450 time
# In U for the 451 time
# In U for the 452 time
# In U for the 453 time
# In U for the 454 time
# In U for the 455 time
# In U for the 456 time
# In U for the 457 time
# In U for the 458 time
# In U for the 459 time
# In U for the 460 time
# In U for the 461 time
# In U for the 462 time
# In U for the 463 time
# In U for the 464 time
# In U for the 465 time
# In U for the 466 time
# In U for the 467 time
# In U for the 468 time
# In U for the 469 time
# In U for the 470 time
# In U for the 471 time
# In U for the 472 time
# In U for the 473 time
# In U for the 474 time
# In U for the 475 time
# In U for the 476 time
# In U for the 477 time
# In U for the 478 time
# In U for the 479 time
# In U for the 480 time
# In U for the 481 time
# In U for the 482 time
# In U for the 483 time
# In U for the 484 time
# In U for the 485 time
# In U for the 486 time
# In U for the 487 time
# In U for the 488 time
# In U for the 489 time
# In U for the 490 time
# In U for the 491 time
# In U for the 492 time
# In U for the 493 time
# In U for the 494 time
# In U for the 495 time
# In U for the 496 time
# In U for the 497 time
# In U for the 498 time
# In U for the 499 time
# In U for the 500 time
# In U for the 501 time
# In U for the 502 time
# In U for the 503 time
# In U for the 504 time
# In U for the 505 time
# In U for the 506 time
# In U for the 507 time
# In U for the 508 time
# In U for the 509 time
# In U for the 510 time
# In U for the 511 time
# In U for the 512 time
# In U for the 513 time
# In U for the 514 time
# In U for the 515 time
# In U for the 516 time
# In U for the 517 time
# In U for the 518 time
# In U for the 519 time
# In U for the 520 time
# In U for the 521 time
# In U for the 522 time
# In U for the 523 time
# In U for the 524 time
# In U for the 525 time
# In U for the 526 time
# In U for the 527 time
# In U for the 528 time
# In U for the 529 time
# In U for the 530 time
# In U for the 531 time
# In U for the 532 time
# In U for the 533 time
# In U for the 534 time
# In U for the 535 time
# In U for the 536 time
# In U for the 537 time
# In U for the 538 time
# In U for the 539 time
# In U for the 540 time
# In U for the 541 time
# In U for the 542 time
# In U for the 543 time
# In U for the 544 time
# In U for the 545 time
# In U for the 546 time
# In U for the 547 time
# In U for the 548 time
# In U for the 549 time
# In U for the 550 time
# In U for the 551 time
# In U for the 552 time
# In U for the 553 time
# In U for the 554 time
# In U for the 555 time
# In U for the 556 time
# In U for the 557 time
# In U for the 558 time
# In U for the 559 time
# In U for the 560 time
# In U for the 561 time
# In U for the 562 time
# In U for the 563 time
# In U for the 564 time
# In U for the 565 time
# In U for the 566 time
# In U for the 567 time
# In U for the 568 time
# In U for the 569 time
# In U for the 570 time
# In U for the 571 time
# In U for the 572 time
# In U for the 573 time
# In U for the 574 time
# In U for the 575 time
# In U for the 576 time
# In U for the 577 time
# In U for the 578 time
# In U for the 579 time
# In U for the 580 time
# In U for the 581 time
# In U for the 582 time
# In U for the 583 time
# In U for the 584 time
# In U for the 585 time
# In U for the 586 time
# In U for the 587 time
# In U for the 588 time
# In U for the 589 time
# In U for the 590 time
# In U for the 591 time
# In U for the 592 time
# In U for the 593 time
# In U for the 594 time
# In U for the 595 time
# In U for the 596 time
# In U for the 597 time
# In U for the 598 time
# In U for the 599 time
# In U for the 600 time
# In U for the 601 time
# In U for the 602 time
# In U for the 603 time
# In U for the 604 time
# In U for the 605 time
# In U for the 606 time
# In U for the 607 time
# In U for the 608 time
# In U for the 609 time
# In U for the 610 time
# In U for the 611 time
# In U for the 612 time
# In U for the 613 time
# In U for the 614 time
# In U for the 615 time
# In U for the 616 time
# In U for the 617 time
# In U for the 618 time
# In U for the 619 time
# In U for the 620 time
# In U for the 621 time
# In U for the 622 time
# In U for the 623 time
# In U for the 624 time
# In U for the 625 time
# In U for the 626 time
# In U for the 627 time
# In U for the 628 time
# In U for the 629 time
# In U for the 630 time
# In U for the 631 time
# In U for the 632 time
# In U for the 633 time
# In U for the 634 time
# In U for the 635 time
# In U for the 636 time
# In U for the 637 time
# In U for the 638 time
# In U for the 639 time
# In U for the 640 time
# In U for the 641 time
# In U for the 642 time
# In U for the 643 time
# In U for the 644 time
# In U for the 645 time
# In U for the 646 time
# In U for the 647 time
# In U for the 648 time
# In U for the 649 time
# In U for the 650 time
# In U for the 651 time
# In U for the 652 time
# In U for the 653 time
# In U for the 654 time
# In U for the 655 time
# In U for the 656 time
# In U for the 657 time
# In U for the 658 time
# In U for the 659 time
# In U for the 660 time
# In U for the 661 time
# In U for the 662 time
# In U for the 663 time
# In U for the 664 time
# In U for the 665 time
# In U for the 666 time
# In U for the 667 time
# In U for the 668 time
# In U for the 669 time
# In U for the 670 time
# In U for the 671 time
# In U for the 672 time
# In U for the 673 time
# In U for the 674 time
# In U for the 675 time
# In U for the 676 time
# In U for the 677 time
# In U for the 678 time
# In U for the 679 time
# In U for the 680 time
# In U for the 681 time
# In U for the 682 time
# In U for the 683 time
# In U for the 684 time
# In U for the 685 time
# In U for the 686 time
# In U for the 687 time
# In U for the 688 time
# In U for the 689 time
# In U for the 690 time
# In U for the 691 time
# In U for the 692 time
# In U for the 693 time
# In U for the 694 time
# In U for the 695 time
# In U for the 696 time
# In U for the 697 time
# In U for the 698 time
# In U for the 699 time
# In U for the 700 time
# In U for the 701 time
# In U for the 702 time
# In U for the 703 time
# In U for the 704 time
# In U for the 705 time
# In U for the 706 time
# In U for the 707 time
# In U for the 708 time
# In U for the 709 time
# In U for the 710 time
# In U for the 711 time
# In U for the 712 time
# In U for the 713 time
# In U for the 714 time
# In U for the 715 time
# In U for the 716 time
# In U for the 717 time
# In U for the 718 time
# In U for the 719 time
# In U for the 720 time
# In U for the 721 time
# In U for the 722 time
# In U for the 723 time
# In U for the 724 time
# In U for the 725 time
# In U for the 726 time
# In U for the 727 time
# In U for the 728 time
# In U for the 729 time
# In U for the 730 time
# In U for the 731 time
# In U for the 732 time
# In U for the 733 time
# In U for the 734 time
# In U for the 735 time
# In U for the 736 time
# In U for the 737 time
# In U for the 738 time
# In U for the 739 time
# In U for the 740 time
# In U for the 741 time
# In U for the 742 time
# In U for the 743 time
# In U for the 744 time
# In U for the 745 time
# In U for the 746 time
# In U for the 747 time
# In U for the 748 time
# In U for the 749 time
# In U for the 750 time
# In U for the 751 time
# In U for the 752 time
# In U for the 753 time
# In U for the 754 time
# In U for the 755 time
# In U for the 756 time
# In U for the 757 time
# In U for the 758 time
# In U for the 759 time
# In U for the 760 time
# In U for the 761 time
# In U for the 762 time
# In U for the 763 time
# In U for the 764 time
# In U for the 765 time
# In U for the 766 time
# In U for the 767 time
# In U for the 768 time
# In U for the 769 time
# In U for the 770 time
# In U for the 771 time
# In U for the 772 time
# In U for the 773 time
# In U for the 774 time
# In U for the 775 time
# In U for the 776 time
# In U for the 777 time
# In U for the 778 time
# In U for the 779 time
# In U for the 780 time
# In U for the 781 time
# In U for the 782 time
# In U for the 783 time
# In U for the 784 time
# In U for the 785 time
# In U for the 786 time
# In U for the 787 time
# In U for the 788 time
# In U for the 789 time
# In U for the 790 time
# In U for the 791 time
# In U for the 792 time
# In U for the 793 time
# In U for the 794 time
# In U for the 795 time
# In U for the 796 time
# In U for the 797 time
# In U for the 798 time
# In U for the 799 time
# In U for the 800 time
# In U for the 801 time
# In U for the 802 time
# In U for the 803 time
# In U for the 804 time
# In U for the 805 time
# In U for the 806 time
# In U for the 807 time
# In U for the 808 time
# In U for the 809 time
# In U for the 810 time
# In U for the 811 time
# In U for the 812 time
# In U for the 813 time
# In U for the 814 time
# In U for the 815 time
# In U for the 816 time
# In U for the 817 time
# In U for the 818 time
# In U for the 819 time
# In U for the 820 time
# In U for the 821 time
# In U for the 822 time
# In U for the 823 time
# In U for the 824 time
# In U for the 825 time
# In U for the 826 time
# In U for the 827 time
# In U for the 828 time
# In U for the 829 time
# In U for the 830 time
# In U for the 831 time
# In U for the 832 time
# In U for the 833 time
# In U for the 834 time
# In U for the 835 time
# In U for the 836 time
# In U for the 837 time
# In U for the 838 time
# In U for the 839 time
# In U for the 840 time
# In U for the 841 time
# In U for the 842 time
# In U for the 843 time
# In U for the 844 time
# In U for the 845 time
# In U for the 846 time
# In U for the 847 time
# In U for the 848 time
# In U for the 849 time
# In U for the 850 time
# In U for the 851 time
# In U for the 852 time
# In U for the 853 time
# In U for the 854 time
# In U for the 855 time
# In U for the 856 time
# In U for the 857 time
# In U for the 858 time
# In U for the 859 time
# In U for the 860 time
# In U for the 861 time
# In U for the 862 time
# In U for the 863 time
# In U for the 864 time
# In U for the 865 time
# In U for the 866 time
# In U for the 867 time
# In U for the 868 time
# In U for the 869 time
# In U for the 870 time
# In U for the 871 time
# In U for the 872 time
# In U for the 873 time
# In U for the 874 time
# In U for the 875 time
# In U for the 876 time
# In U for the 877 time
# In U for the 878 time
# In U for the 879 time
# In U for the 880 time
# In U for the 881 time
# In U for the 882 time
# In U for the 883 time
# In U for the 884 time
# In U for the 885 time
# In U for the 886 time
# In U for the 887 time
# In U for the 888 time
# In U for the 889 time
# In U for the 890 time
# In U for the 891 time
# In U for the 892 time
# In U for the 893 time
# In U for the 894 time
# In U for the 895 time
# In U for the 896 time
# In U for the 897 time
# In U for the 898 time
# In U for the 899 time
# In U for the 900 time
# In U for the 901 time
# In U for the 902 time
# In U for the 903 time
# In U for the 904 time
# In U for the 905 time
# In U for the 906 time
# In U for the 907 time
# In U for the 908 time
# In U for the 909 time
# In U for the 910 time
# In U for the 911 time
# In U for the 912 time
# In U for the 913 time
# In U for the 914 time
# In U for the 915 time
# In U for the 916 time
# In U for the 917 time
# In U for the 918 time
# In U for the 919 time
# In U for the 920 time
# In U for the 921 time
# In U for the 922 time
# In U for the 923 time
# In U for the 924 time
# In U for the 925 time
# In U for the 926 time
# In U for the 927 time
# In U for the 928 time
# In U for the 929 time
# In U for the 930 time
# In U for the 931 time
# In U for the 932 time
# In U for the 933 time
# In U for the 934 time
# In U for the 935 time
# In U for the 936 time
# In U for the 937 time
# In U for the 938 time
# In U for the 939 time
# In U for the 940 time
# In U for the 941 time
# In U for the 942 time
# In U for the 943 time
# In U for the 944 time
# In U for the 945 time
# In U for the 946 time
# In U for the 947 time
# In U for the 948 time
# In U for the 949 time
# In U for the 950 time
# In U for the 951 time
# In U for the 952 time
# In U for the 953 time
# In U for the 954 time
# In U for the 955 time
# In U for the 956 time
# In U for the 957 time
# In U for the 958 time
# In U for the 959 time
# In U for the 960 time
# In U for the 961 time
# In U for the 962 time
# In U for the 963 time
# In U for the 964 time
# In U for the 965 time
# In U for the 966 time
# In U for the 967 time
# In U for the 968 time
# In U for the 969 time
# In U for the 970 time
# In U for the 971 time
# In U for the 972 time
# In U for the 973 time
# In U for the 974 time
# In U for the 975 time
# In U for the 976 time
# In U for the 977 time
# In U for the 978 time
# In U for the 979 time
# In U for the 980 time
# In U for the 981 time
# In U for the 982 time
# In U for the 983 time
# In U for the 984 time
# In U for the 985 time
# In U for the 986 time
# In U for the 987 time
# In U for the 988 time
# In U for the 989 time
# In U for the 990 time
# In U for the 991 time
# In U for the 992 time
# In U for the 993 time
# In U for the 994 time
# In U for the 995 time
# In U for the 996 time
# In U for the 997 time
# In U for the 998 time
# In U for the 999 time
# In U for the 1000 time
# In U for the 1001 time
# In U for the 1002 time
# In U for the 1003 time
# In U for the 1004 time
# In U for the 1005 time
# In U for the 1006 time
# In U for the 1007 time
# In U for the 1008 time
# In U for the 1009 time
# In U for the 1010 time
# In U for the 1011 time
# In U for the 1012 time
# In U for the 1013 time
# In U for the 1014 time
# In U for the 1015 time
# In U for the 1016 time
# In U for the 1017 time
# In U for the 1018 time
# In U for the 1019 time
# In U for the 1020 time
# In U for the 1021 time
# In U for the 1022 time
# In U for the 1023 time
# In U for the 1024 time
# In U for the 1025 time
# In U for the 1026 time
# In U for the 1027 time
# In U for the 1028 time
# In U for the 1029 time
# In U for the 1030 time
# In U for the 1031 time
# In U for the 1032 time
# In U for the 1033 time
# In U for the 1034 time
# In U for the 1035 time
# In U for the 1036 time
# In U for the 1037 time
# In U for the 1038 time
# In U for the 1039 time
# In U for the 1040 time
# In U for the 1041 time
# In U for the 1042 time
# In U for the 1043 time
# In U for the 1044 time
# In U for the 1045 time
# In U for the 1046 time
# In U for the 1047 time
# In U for the 1048 time
# In U for the 1049 time
# In U for the 1050 time
# In U for the 1051 time
# In U for the 1052 time
# In U for the 1053 time
# In U for the 1054 time
# In U for the 1055 time
# In U for the 1056 time
# In U for the 1057 time
# In U for the 1058 time
# In U for the 1059 time
# In U for the 1060 time
# In U for the 1061 time
# In U for the 1062 time
# In U for the 1063 time
# In U for the 1064 time
# In U for the 1065 time
# In U for the 1066 time
# In U for the 1067 time
# In U for the 1068 time
# In U for the 1069 time
# In U for the 1070 time
# In U for the 1071 time
# In U for the 1072 time
# In U for the 1073 time
# In U for the 1074 time
# In U for the 1075 time
# In U for the 1076 time
# In U for the 1077 time
# In U for the 1078 time
# In U for the 1079 time
# In U for the 1080 time
# In U for the 1081 time
# In U for the 1082 time
# In U for the 1083 time
# In U for the 1084 time
# In U for the 1085 time
# In U for the 1086 time
# In U for the 1087 time
# In U for the 1088 time
# In U for the 1089 time
# In U for the 1090 time
# In U for the 1091 time
# In U for the 1092 time
# In U for the 1093 time
# In U for the 1094 time
# In U for the 1095 time
# In U for the 1096 time
# In U for the 1097 time
# In U for the 1098 time
# In U for the 1099 time
# In U for the 1100 time
# In U for the 1101 time
# In U for the 1102 time
# In U for the 1103 time
# In U for the 1104 time
# In U for the 1105 time
# In U for the 1106 time
# In U for the 1107 time
# In U for the 1108 time
# In U for the 1109 time
# In U for the 1110 time
# In U for the 1111 time
# In U for the 1112 time
# In U for the 1113 time
# In U for the 1114 time
# In U for the 1115 time
# In U for the 1116 time
# In U for the 1117 time
# In U for the 1118 time
# In U for the 1119 time
# In U for the 1120 time
# In U for the 1121 time
# In U for the 1122 time
# In U for the 1123 time
# In U for the 1124 time
# In U for the 1125 time
# In U for the 1126 time
# In U for the 1127 time
# In U for the 1128 time
# In U for the 1129 time
# In U for the 1130 time
# In U for the 1131 time
# In U for the 1132 time
# In U for the 1133 time
# In U for the 1134 time
# In U for the 1135 time
# In U for the 1136 time
# In U for the 1137 time
# In U for the 1138 time
# In U for the 1139 time
# In U for the 1140 time
# In U for the 1141 time
# In U for the 1142 time
# In U for the 1143 time
# In U for the 1144 time
# In U for the 1145 time
# In U for the 1146 time
# In U for the 1147 time
# In U for the 1148 time
# In U for the 1149 time
# In U for the 1150 time
# In U for the 1151 time
# In U for the 1152 time
# In U for the 1153 time
# In U for the 1154 time
# In U for the 1155 time
# In U for the 1156 time
# In U for the 1157 time
# In U for the 1158 time
# In U for the 1159 time
# In U for the 1160 time
# In U for the 1161 time
# In U for the 1162 time
# In U for the 1163 time
# In U for the 1164 time
# In U for the 1165 time
# In U for the 1166 time
# In U for the 1167 time
# In U for the 1168 time
# In U for the 1169 time
# In U for the 1170 time
# In U for the 1171 time
# In U for the 1172 time
# In U for the 1173 time
# In U for the 1174 time
# In U for the 1175 time
# In U for the 1176 time
# In U for the 1177 time
# In U for the 1178 time
# In U for the 1179 time
# In U for the 1180 time
# In U for the 1181 time
# In U for the 1182 time
# In U for the 1183 time
# In U for the 1184 time
# In U for the 1185 time
# In U for the 1186 time
# In U for the 1187 time
# In U for the 1188 time
# In U for the 1189 time
# In U for the 1190 time
# In U for the 1191 time
# In U for the 1192 time
# In U for the 1193 time
# In U for the 1194 time
# In U for the 1195 time
# In U for the 1196 time
# In U for the 1197 time
# In U for the 1198 time
# In U for the 1199 time
# In U for the 1200 time
# In U for the 1201 time
# In U for the 1202 time
# In U for the 1203 time
# In U for the 1204 time
# In U for the 1205 time
# In U for the 1206 time
# In U for the 1207 time
# In U for the 1208 time
# In U for the 1209 time
# In U for the 1210 time
# In U for the 1211 time
# In U for the 1212 time
# In U for the 1213 time
# In U for the 1214 time
# In U for the 1215 time
# In U for the 1216 time
# In U for the 1217 time
# In U for the 1218 time
# In U for the 1219 time
# In U for the 1220 time
# In U for the 1221 time
# In U for the 1222 time
# In U for the 1223 time
# In U for the 1224 time
# In U for the 1225 time
# In U for the 1226 time
# In U for the 1227 time
# In U for the 1228 time
# In U for the 1229 time
# In U for the 1230 time
# In U for the 1231 time
# In U for the 1232 time
# In U for the 1233 time
# In U for the 1234 time
# In U for the 1235 time
# In U for the 1236 time
# In U for the 1237 time
# In U for the 1238 time
# In U for the 1239 time
# In U for the 1240 time
# In U for the 1241 time
# In U for the 1242 time
# In U for the 1243 time
# In U for the 1244 time
# In U for the 1245 time
# In U for the 1246 time
# In U for the 1247 time
# In U for the 1248 time
# In U for the 1249 time
# In U for the 1250 time
# In U for the 1251 time
# In U for the 1252 time
# In U for the 1253 time
# In U for the 1254 time
# In U for the 1255 time
# In U for the 1256 time
# In U for the 1257 time
# In U for the 1258 time
# In U for the 1259 time
# In U for the 1260 time
# In U for the 1261 time
# In U for the 1262 time
# In U for the 1263 time
# In U for the 1264 time
# In U for the 1265 time
# In U for the 1266 time
# In U for the 1267 time
# In U for the 1268 time
# In U for the 1269 time
# In U for the 1270 time
# In U for the 1271 time
# In U for the 1272 time
# In U for the 1273 time
# In U for the 1274 time
# In U for the 1275 time
# In U for the 1276 time
# In U for the 1277 time
# In U for the 1278 time
# In U for the 1279 time
# In U for the 1280 time
# In U for the 1281 time
# In U for the 1282 time
# In U for the 1283 time
# In U for the 1284 time
# In U for the 1285 time
# In U for the 1286 time
# In U for the 1287 time
# In U for the 1288 time
# In U for the 1289 time
# In U for the 1290 time
# In U for the 1291 time
# In U for the 1292 time
# In U for the 1293 time
# In U for the 1294 time
# In U for the 1295 time
# In U for the 1296 time
# In U for the 1297 time
# In U for the 1298 time
# In U for the 1299 time
# In U for the 1300 time
# In U for the 1301 time
# In U for the 1302 time
# In U for the 1303 time
# In U for the 1304 time
# In U for the 1305 time
# In U for the 1306 time
# In U for the 1307 time
# In U for the 1308 time
# In U for the 1309 time
# In U for the 1310 time
# In U for the 1311 time
# In U for the 1312 time
# In U for the 1313 time
# In U for the 1314 time
# In U for the 1315 time
# In U for the 1316 time
# In U for the 1317 time
# In U for the 1318 time
# In U for the 1319 time
# In U for the 1320 time
# In U for the 1321 time
# In U for the 1322 time
# In U for the 1323 time
# In U for the 1324 time
# In U for the 1325 time
# In U for the 1326 time
# In U for the 1327 time
# In U for the 1328 time
# In U for the 1329 time
# In U for the 1330 time
# In U for the 1331 time
# In U for the 1332 time
# In U for the 1333 time
# In U for the 1334 time
# In U for the 1335 time
# In U for the 1336 time
# In U for the 1337 time
# In U for the 1338 time
# In U for the 1339 time
# In U for the 1340 time
# In U for the 1341 time
# In U for the 1342 time
# In U for the 1343 time
# In U for the 1344 time
# In U for the 1345 time
# In U for the 1346 time
# In U for the 1347 time
# In U for the 1348 time
# In U for the 1349 time
# In U for the 1350 time
# In U for the 1351 time
# In U for the 1352 time
# In U for the 1353 time
# In U for the 1354 time
# In U for the 1355 time
# In U for the 1356 time
# In U for the 1357 time
# In U for the 1358 time
# In U for the 1359 time
# In U for the 1360 time
# In U for the 1361 time
# In U for the 1362 time
# In U for the 1363 time
# In U for the 1364 time
# In U for the 1365 time
# In U for the 1366 time
# In U for the 1367 time
# In U for the 1368 time
# In U for the 1369 time
# In U for the 1370 time
# In U for the 1371 time
# In U for the 1372 time
# In U for the 1373 time
# In U for the 1374 time
# In U for the 1375 time
# In U for the 1376 time
# In U for the 1377 time
# In U for the 1378 time
# In U for the 1379 time
# In U for the 1380 time
# In U for the 1381 time
# In U for the 1382 time
# In U for the 1383 time
# In U for the 1384 time
# In U for the 1385 time
# In U for the 1386 time
# In U for the 1387 time
# In U for the 1388 time
# In U for the 1389 time
# In U for the 1390 time
# In U for the 1391 time
# In U for the 1392 time
# In U for the 1393 time
# In U for the 1394 time
# In U for the 1395 time
# In U for the 1396 time
# In U for the 1397 time
# In U for the 1398 time
# In U for the 1399 time
# In U for the 1400 time
# In U for the 1401 time
# In U for the 1402 time
# In U for the 1403 time
# In U for the 1404 time
# In U for the 1405 time
# In U for the 1406 time
# In U for the 1407 time
# In U for the 1408 time
# In U for the 1409 time
# In U for the 1410 time
# In U for the 1411 time
# In U for the 1412 time
# In U for the 1413 time
# In U for the 1414 time
# In U for the 1415 time
# In U for the 1416 time
# In U for the 1417 time
# In U for the 1418 time
# In U for the 1419 time
# In U for the 1420 time
# In U for the 1421 time
# In U for the 1422 time
# In U for the 1423 time
# In U for the 1424 time
# In U for the 1425 time
# In U for the 1426 time
# In U for the 1427 time
# In U for the 1428 time
# In U for the 1429 time
# In U for the 1430 time
# In U for the 1431 time
# In U for the 1432 time
# In U for the 1433 time
# In U for the 1434 time
# In U for the 1435 time
# In U for the 1436 time
# In U for the 1437 time
# In U for the 1438 time
# In U for the 1439 time
# In U for the 1440 time
# In U for the 1441 time
# In U for the 1442 time
# In U for the 1443 time
# In U for the 1444 time
# In U for the 1445 time
# In U for the 1446 time
# In U for the 1447 time
# In U for the 1448 time
# In U for the 1449 time
# In U for the 1450 time
# In U for the 1451 time
# In U for the 1452 time
# In U for the 1453 time
# In U for the 1454 time
# In U for the 1455 time
# In U for the 1456 time
# In U for the 1457 time
# In U for the 1458 time
# In U for the 1459 time
# In U for the 1460 time
# In U for the 1461 time
# In U for the 1462 time
# In U for the 1463 time
# In U for the 1464 time
# In U for the 1465 time
# In U for the 1466 time
# In U for the 1467 time
# In U for the 1468 time
# In U for the 1469 time
# In U for the 1470 time
# In U for the 1471 time
# In U for the 1472 time
# In U for the 1473 time
# In U for the 1474 time
# In U for the 1475 time
# In U for the 1476 time
# In U for the 1477 time
# In U for the 1478 time
# In U for the 1479 time
# In U for the 1480 time
# In U for the 1481 time
# In U for the 1482 time
# In U for the 1483 time
# In U for the 1484 time
# In U for the 1485 time
# In U for the 1486 time
# In U for the 1487 time
# In U for the 1488 time
# In U for the 1489 time
# In U for the 1490 time
# In U for the 1491 time
# In U for the 1492 time
# In U for the 1493 time
# In U for the 1494 time
# In U for the 1495 time
# In U for the 1496 time
# In U for the 1497 time
# In U for the 1498 time
# In U for the 1499 time
# In U for the 1500 time
# In U for the 1501 time
# In U for the 1502 time
# In U for the 1503 time
# In U for the 1504 time
# In U for the 1505 time
# In U for the 1506 time
# In U for the 1507 time
# In U for the 1508 time
# In U for the 1509 time
# In U for the 1510 time
# In U for the 1511 time
# In U for the 1512 time
# In U for the 1513 time
# In U for the 1514 time
# In U for the 1515 time
# In U for the 1516 time
# In U for the 1517 time
# In U for the 1518 time
# In U for the 1519 time
# In U for the 1520 time
# In U for the 1521 time
# In U for the 1522 time
# In U for the 1523 time
# In U for the 1524 time
# In U for the 1525 time
# In U for the 1526 time
# In U for the 1527 time
# In U for the 1528 time
# In U for the 1529 time
# In U for the 1530 time
# In U for the 1531 time
# In U for the 1532 time
# In U for the 1533 time
# In U for the 1534 time
# In U for the 1535 time
# In U for the 1536 time
# In U for the 1537 time
# In U for the 1538 time
# In U for the 1539 time
# In U for the 1540 time
# In U for the 1541 time
# In U for the 1542 time
# In U for the 1543 time
# In U for the 1544 time
# In U for the 1545 time
# In U for the 1546 time
# In U for the 1547 time
# In U for the 1548 time
# In U for the 1549 time
# In U for the 1550 time
# In U for the 1551 time
# In U for the 1552 time
# In U for the 1553 time
# In U for the 1554 time
# In U for the 1555 time
# In U for the 1556 time
# In U for the 1557 time
# In U for the 1558 time
# In U for the 1559 time
# In U for the 1560 time
# In U for the 1561 time
# In U for the 1562 time
# In U for the 1563 time
# In U for the 1564 time
# In U for the 1565 time
# In U for the 1566 time
# In U for the 1567 time
# In U for the 1568 time
# In U for the 1569 time
# In U for the 1570 time
# In U for the 1571 time
# In U for the 1572 time
# In U for the 1573 time
# In U for the 1574 time
# In U for the 1575 time
# In U for the 1576 time
# In U for the 1577 time
# In U for the 1578 time
# In U for the 1579 time
# In U for the 1580 time
# In U for the 1581 time
# In U for the 1582 time
# In U for the 1583 time
# In U for the 1584 time
# In U for the 1585 time
# In U for the 1586 time
# In U for the 1587 time
# In U for the 1588 time
# In U for the 1589 time
# In U for the 1590 time
# In U for the 1591 time
# In U for the 1592 time
# In U for the 1593 time
# In U for the 1594 time
# In U for the 1595 time
# In U for the 1596 time
# In U for the 1597 time
# In U for the 1598 time
# In U for the 1599 time
# In U for the 1600 time
# In U for the 1601 time
# In U for the 1602 time
# In U for the 1603 time
# In U for the 1604 time
# In U for the 1605 time
# In U for the 1606 time
# In U for the 1607 time
# In U for the 1608 time
# In U for the 1609 time
# In U for the 1610 time
# In U for the 1611 time
# In U for the 1612 time
# In U for the 1613 time
# In U for the 1614 time
# In U for the 1615 time
# In U for the 1616 time
# In U for the 1617 time
# In U for the 1618 time
# In U for the 1619 time
# In U for the 1620 time
# In U for the 1621 time
# In U for the 1622 time
# In U for the 1623 time
# In U for the 1624 time
# In U for the 1625 time
# In U for the 1626 time
# In U for the 1627 time
# In U for the 1628 time
# In U for the 1629 time
# In U for the 1630 time
# In U for the 1631 time
# In U for the 1632 time
# In U for the 1633 time
# In U for the 1634 time
# In U for the 1635 time
# In U for the 1636 time
# In U for the 1637 time
# In U for the 1638 time
# In U for the 1639 time
# In U for the 1640 time
# In U for the 1641 time
# In U for the 1642 time
# In U for the 1643 time
# In U for the 1644 time
# In U for the 1645 time
# In U for the 1646 time
# In U for the 1647 time
# In U for the 1648 time
# In U for the 1649 time
# In U for the 1650 time
# In U for the 1651 time
# In U for the 1652 time
# In U for the 1653 time
# In U for the 1654 time
# In U for the 1655 time
# In U for the 1656 time
# In U for the 1657 time
# In U for the 1658 time
# In U for the 1659 time
# In U for the 1660 time
# In U for the 1661 time
# In U for the 1662 time
# In U for the 1663 time
# In U for the 1664 time
# In U for the 1665 time
# In U for the 1666 time
# In U for the 1667 time
# In U for the 1668 time
# In U for the 1669 time
# In U for the 1670 time
# In U for the 1671 time
# In U for the 1672 time
# In U for the 1673 time
# In U for the 1674 time
# In U for the 1675 time
# In U for the 1676 time
# In U for the 1677 time
# In U for the 1678 time
# In U for the 1679 time
# In U for the 1680 time
# In U for the 1681 time
# In U for the 1682 time
# In U for the 1683 time
# In U for the 1684 time
# In U for the 1685 time
# In U for the 1686 time
# In U for the 1687 time
# In U for the 1688 time
# In U for the 1689 time
# In U for the 1690 time
# In U for the 1691 time
# In U for the 1692 time
# In U for the 1693 time
# In U for the 1694 time
# In U for the 1695 time
# In U for the 1696 time
# In U for the 1697 time
# In U for the 1698 time
# In U for the 1699 time
# In U for the 1700 time
# In U for the 1701 time
# In U for the 1702 time
# In U for the 1703 time
# In U for the 1704 time
# In U for the 1705 time
# In U for the 1706 time
# In U for the 1707 time
# In U for the 1708 time
# In U for the 1709 time
# In U for the 1710 time
# In U for the 1711 time
# In U for the 1712 time
# In U for the 1713 time
# In U for the 1714 time
# In U for the 1715 time
# In U for the 1716 time
# In U for the 1717 time
# In U for the 1718 time
# In U for the 1719 time
# In U for the 1720 time
# In U for the 1721 time
# In U for the 1722 time
# In U for the 1723 time
# In U for the 1724 time
# In U for the 1725 time
# In U for the 1726 time
# In U for the 1727 time
# In U for the 1728 time
# In U for the 1729 time
# In U for the 1730 time
# In U for the 1731 time
# In U for the 1732 time
# In U for the 1733 time
# In U for the 1734 time
# In U for the 1735 time
# In U for the 1736 time
# In U for the 1737 time
# In U for the 1738 time
# In U for the 1739 time
# In U for the 1740 time
# In U for the 1741 time
# In U for the 1742 time
# In U for the 1743 time
# In U for the 1744 time
# In U for the 1745 time
# In U for the 1746 time
# In U for the 1747 time
# In U for the 1748 time
# In U for the 1749 time
# In U for the 1750 time
# In U for the 1751 time
# In U for the 1752 time
# In U for the 1753 time
# In U for the 1754 time
# In U for the 1755 time
# In U for the 1756 time
# In U for the 1757 time
# In U for the 1758 time
# In U for the 1759 time
# In U for the 1760 time
# In U for the 1761 time
# In U for the 1762 time
# In U for the 1763 time
# In U for the 1764 time
# In U for the 1765 time
# In U for the 1766 time
# In U for the 1767 time
# In U for the 1768 time
# In U for the 1769 time
# In U for the 1770 time
# In U for the 1771 time
# In U for the 1772 time
# In U for the 1773 time
# In U for the 1774 time
# In U for the 1775 time
# In U for the 1776 time
# In U for the 1777 time
# In U for the 1778 time
# In U for the 1779 time
# In U for the 1780 time
# In U for the 1781 time
# In U for the 1782 time
# In U for the 1783 time
# In U for the 1784 time
# In U for the 1785 time
# In U for the 1786 time
# In U for the 1787 time
# In U for the 1788 time
# In U for the 1789 time
# In U for the 1790 time
# In U for the 1791 time
# In U for the 1792 time
# In U for the 1793 time
# In U for the 1794 time
# In U for the 1795 time
# In U for the 1796 time
# In U for the 1797 time
# In U for the 1798 time
# In U for the 1799 time
# In U for the 1800 time
# In U for the 1801 time
# In U for the 1802 time
# In U for the 1803 time
# In U for the 1804 time
# In U for the 1805 time
# In U for the 1806 time
# In U for the 1807 time
# In U for the 1808 time
# In U for the 1809 time
# In U for the 1810 time
# In U for the 1811 time
# In U for the 1812 time
# In U for the 1813 time
# In U for the 1814 time
# In U for the 1815 time
# In U for the 1816 time
# In U for the 1817 time
# In U for the 1818 time
# In U for the 1819 time
# In U for the 1820 time
# In U for the 1821 time
# In U for the 1822 time
# In U for the 1823 time
# In U for the 1824 time
# In U for the 1825 time
# In U for the 1826 time
# In U for the 1827 time
# In U for the 1828 time
# In U for the 1829 time
# In U for the 1830 time
# In U for the 1831 time
# In U for the 1832 time
# In U for the 1833 time
# In U for the 1834 time
# In U for the 1835 time
# In U for the 1836 time
# In U for the 1837 time
# In U for the 1838 time
# In U for the 1839 time
# In U for the 1840 time
# In U for the 1841 time
# In U for the 1842 time
# In U for the 1843 time
# In U for the 1844 time
# In U for the 1845 time
# In U for the 1846 time
# In U for the 1847 time
# In U for the 1848 time
# In U for the 1849 time
# In U for the 1850 time
# In U for the 1851 time
# In U for the 1852 time
# In U for the 1853 time
# In U for the 1854 time
# In U for the 1855 time
# In U for the 1856 time
# In U for the 1857 time
# In U for the 1858 time
# In U for the 1859 time
# In U for the 1860 time
# In U for the 1861 time
# In U for the 1862 time
# In U for the 1863 time
# In U for the 1864 time
# In U for the 1865 time
# In U for the 1866 time
# In U for the 1867 time
# In U for the 1868 time
# In U for the 1869 time
# In U for the 1870 time
# In U for the 1871 time
# In U for the 1872 time
# In U for the 1873 time
# In U for the 1874 time
# In U for the 1875 time
# In U for the 1876 time
# In U for the 1877 time
# In U for the 1878 time
# In U for the 1879 time
# In U for the 1880 time
# In U for the 1881 time
# In U for the 1882 time
# In U for the 1883 time
# In U for the 1884 time
# In U for the 1885 time
# In U for the 1886 time
# In U for the 1887 time
# In U for the 1888 time
# In U for the 1889 time
# In U for the 1890 time
# In U for the 1891 time
# In U for the 1892 time
# In U for the 1893 time
# In U for the 1894 time
# In U for the 1895 time
# In U for the 1896 time
# In U for the 1897 time
# In U for the 1898 time
# In U for the 1899 time
# In U for the 1900 time
# In U for the 1901 time
# In U for the 1902 time
# In U for the 1903 time
# In U for the 1904 time
# In U for the 1905 time
# In U for the 1906 time
# In U for the 1907 time
# In U for the 1908 time
# In U for the 1909 time
# In U for the 1910 time
# In U for the 1911 time
# In U for the 1912 time
# In U for the 1913 time
# In U for the 1914 time
# In U for the 1915 time
# In U for the 1916 time
# In U for the 1917 time
# In U for the 1918 time
# In U for the 1919 time
# In U for the 1920 time
# In U for the 1921 time
# In U for the 1922 time
# In U for the 1923 time
# In U for the 1924 time
# In U for the 1925 time
# In U for the 1926 time
# In U for the 1927 time
# In U for the 1928 time
# In U for the 1929 time
# In U for the 1930 time
# In U for the 1931 time
# In U for the 1932 time
# In U for the 1933 time
# In U for the 1934 time
# In U for the 1935 time
# In U for the 1936 time
# In U for the 1937 time
# In U for the 1938 time
# In U for the 1939 time
# In U for the 1940 time
# In U for the 1941 time
# In U for the 1942 time
# In U for the 1943 time
# In U for the 1944 time
# In U for the 1945 time
# In U for the 1946 time
# In U for the 1947 time
# In U for the 1948 time
# In U for the 1949 time
# In U for the 1950 time
# In U for the 1951 time
# In U for the 1952 time
# In U for the 1953 time
# In U for the 1954 time
# In U for the 1955 time
# In U for the 1956 time
# In U for the 1957 time
# In U for the 1958 time
# In U for the 1959 time
# In U for the 1960 time
# In U for the 1961 time
# In U for the 1962 time
# In U for the 1963 time
# In U for the 1964 time
# In U for the 1965 time
# In U for the 1966 time
# In U for the 1967 time
# In U for the 1968 time
# In U for the 1969 time
# In U for the 1970 time
# In U for the 1971 time
# In U for the 1972 time
# In U for the 1973 time
# In U for the 1974 time
# In U for the 1975 time
# In U for the 1976 time
# In U for the 1977 time
# In U for the 1978 time
# In U for the 1979 time
# In U for the 1980 time
# In U for the 1981 time
# In U for the 1982 time
# In U for the 1983 time
# In U for the 1984 time
# In U for the 1985 time
# In U for the 1986 time
# In U for the 1987 time
# In U for the 1988 time
# In U for the 1989 time
# In U for the 1990 time
# In U for the 1991 time
# In U for the 1992 time
# In U for the 1993 time
# In U for the 1994 time
# In U for the 1995 time
# In U for the 1996 time
# In U for the 1997 time
# In U for the 1998 time
# In U for the 1999 time
# In U for the 2000 time
# In U for the 2001 time
# In U for the 2002 time
# In U for the 2003 time
# In U for the 2004 time
# In U for the 2005 time
# In U for the 2006 time
# In U for the 2007 time
# In U for the 2008 time
# In U for the 2009 time
# In U for the 2010 time
# In U for the 2011 time
# In U for the 2012 time
# In U for the 2013 time
# In U for the 2014 time
# In U for the 2015 time
# In U for the 2016 time
# In U for the 2017 time
# In U for the 2018 time
# In U for the 2019 time
# In U for the 2020 time
# In U for the 2021 time
# In U for the 2022 time
# In U for the 2023 time
# In U for the 2024 time
# In U for the 2025 time
# In U for the 2026 time
# In U for the 2027 time
# In U for the 2028 time
# In U for the 2029 time
# In U for the 2030 time
# In U for the 2031 time
# In U for the 2032 time
# In U for the 2033 time
# In U for the 2034 time
# In U for the 2035 time
# In U for the 2036 time
# In U for the 2037 time
# In U for the 2038 time
# In U for the 2039 time
# In U for the 2040 time
# In U for the 2041 time
# In U for the 2042 time
# In U for the 2043 time
# In U for the 2044 time
# In U for the 2045 time
# In U for the 2046 time
# In U for the 2047 time
# In U for the 2048 time
# In U for the 2049 time
# In U for the 2050 time
# In U for the 2051 time
# In U for the 2052 time
# In U for the 2053 time
# In U for the 2054 time
# In U for the 2055 time
# In U for the 2056 time
# In U for the 2057 time
# In U for the 2058 time
# In U for the 2059 time
# In U for the 2060 time
# In U for the 2061 time
# In U for the 2062 time
# In U for the 2063 time
# In U for the 2064 time
# In U for the 2065 time
# In U for the 2066 time
# In U for the 2067 time
# In U for the 2068 time
# In U for the 2069 time
# In U for the 2070 time
# In U for the 2071 time
# In U for the 2072 time
# In U for the 2073 time
# In U for the 2074 time
# In U for the 2075 time
# In U for the 2076 time
# In U for the 2077 time
# In U for the 2078 time
# In U for the 2079 time
# In U for the 2080 time
# In U for the 2081 time
# In U for the 2082 time
# In U for the 2083 time
# In U for the 2084 time
# In U for the 2085 time
# In U for the 2086 time
# In U for the 2087 time
# In U for the 2088 time
# In U for the 2089 time
# In U for the 2090 time
# In U for the 2091 time
# In U for the 2092 time
# In U for the 2093 time
# In U for the 2094 time
# In U for the 2095 time
# In U for the 2096 time
# In U for the 2097 time
# In U for the 2098 time
# In U for the 2099 time
# In U for the 2100 time
# In U for the 2101 time
# In U for the 2102 time
# In U for the 2103 time
# In U for the 2104 time
# In U for the 2105 time
# In U for the 2106 time
# In U for the 2107 time
# In U for the 2108 time
# In U for the 2109 time
# In U for the 2110 time
# In U for the 2111 time
# In U for the 2112 time
# In U for the 2113 time
# In U for the 2114 time
# In U for the 2115 time
# In U for the 2116 time
# In U for the 2117 time
# In U for the 2118 time
# In U for the 2119 time
# In U for the 2120 time
# In U for the 2121 time
# In U for the 2122 time
# In U for the 2123 time
# In U for the 2124 time
# In U for the 2125 time
# In U for the 2126 time
# In U for the 2127 time
# In U for the 2128 time
# In U for the 2129 time
# In U for the 2130 time
# In U for the 2131 time
# In U for the 2132 time
# In U for the 2133 time
# ...
# In I for the 73107 time
# In I for the 73108 time
# In I for the 73109 time
# In I for the 73110 time
# In I for the 73111 time
# In I for the 73112 time
# In I for the 73113 time
# In I for the 73114 time
# In I for the 73115 time
# In I for the 73116 time
# In I for the 73117 time
# In I for the 73118 time
# In I for the 73119 time
# In I for the 73120 time
# In I for the 73121 time
# In I for the 73122 time
# In I for the 73123 time
# In I for the 73124 time
# In I for the 73125 time
# In I for the 73126 time
# In I for the 73127 time
# In I for the 73128 time
# In I for the 73129 time
# In I for the 73130 time
# In I for the 73131 time
# In I for the 73132 time
# In I for the 73133 time
# In I for the 73134 time
# In I for the 73135 time
# In I for the 73136 time
# In I for the 73137 time
# In I for the 73138 time
# In I for the 73139 time
# In I for the 73140 time
# In I for the 73141 time
# In I for the 73142 time
# In I for the 73143 time
# In I for the 73144 time
# In I for the 73145 time
# In I for the 73146 time
# In I for the 73147 time
# In I for the 73148 time
# In I for the 73149 time
# In I for the 73150 time
# In I for the 73151 time
# In I for the 73152 time
# In I for the 73153 time
# In I for the 73154 time
# In I for the 73155 time
# In I for the 73156 time
# In I for the 73157 time
# In I for the 73158 time
# In I for the 73159 time
# In I for the 73160 time
# In I for the 73161 time
# In I for the 73162 time
# In I for the 73163 time
# In I for the 73164 time
# In I for the 73165 time
# In I for the 73166 time
# In I for the 73167 time
# In I for the 73168 time
# In I for the 73169 time
# In I for the 73170 time
# In I for the 73171 time
# In I for the 73172 time
# In I for the 73173 time
# In I for the 73174 time
# In I for the 73175 time
# In I for the 73176 time
# In I for the 73177 time
# In I for the 73178 time
# In I for the 73179 time
# In I for the 73180 time
# In I for the 73181 time
# In I for the 73182 time
# In I for the 73183 time
# In I for the 73184 time
# In I for the 73185 time
# In I for the 73186 time
# In I for the 73187 time
# In I for the 73188 time
# In I for the 73189 time
# In I for the 73190 time
# In I for the 73191 time
# In I for the 73192 time
# In I for the 73193 time
# In I for the 73194 time
# In I for the 73195 time
# In I for the 73196 time
# In I for the 73197 time
# In I for the 73198 time
# In I for the 73199 time
# In I for the 73200 time
# In I for the 73201 time
# In I for the 73202 time
# In I for the 73203 time
# In I for the 73204 time
# In I for the 73205 time
# In I for the 73206 time
# In I for the 73207 time
# In I for the 73208 time
# In I for the 73209 time
# In I for the 73210 time
# In I for the 73211 time
# In I for the 73212 time
# In I for the 73213 time
# In I for the 73214 time
# In I for the 73215 time
# In I for the 73216 time
# In I for the 73217 time
# In I for the 73218 time
# In I for the 73219 time
# In I for the 73220 time
# In I for the 73221 time
# In I for the 73222 time
# In I for the 73223 time
# In I for the 73224 time
# In I for the 73225 time
# In I for the 73226 time
# In I for the 73227 time
# In I for the 73228 time
# In I for the 73229 time
# In I for the 73230 time
# In I for the 73231 time
# In I for the 73232 time
# In I for the 73233 time
# In I for the 73234 time
# In I for the 73235 time
# In I for the 73236 time
# In I for the 73237 time
# In I for the 73238 time
# In I for the 73239 time
# In I for the 73240 time
# In I for the 73241 time
# In I for the 73242 time
# In I for the 73243 time
# In I for the 73244 time
# In I for the 73245 time
# In I for the 73246 time
# In I for the 73247 time
# In I for the 73248 time
# In I for the 73249 time
# In I for the 73250 time
# In I for the 73251 time
# In I for the 73252 time
# In I for the 73253 time
# In I for the 73254 time
# In I for the 73255 time
# In I for the 73256 time
# In I for the 73257 time
# In I for the 73258 time
# In I for the 73259 time
# In I for the 73260 time
# In I for the 73261 time
# In I for the 73262 time
# In I for the 73263 time
# In I for the 73264 time
# In I for the 73265 time
# In I for the 73266 time
# In I for the 73267 time
# In I for the 73268 time
# In I for the 73269 time
# In I for the 73270 time
# In I for the 73271 time
# In I for the 73272 time
# In I for the 73273 time
# In I for the 73274 time
# In I for the 73275 time
# In I for the 73276 time
# In I for the 73277 time
# In I for the 73278 time
# In I for the 73279 time
# In I for the 73280 time
# In I for the 73281 time
# In I for the 73282 time
# In I for the 73283 time
# In I for the 73284 time
# In I for the 73285 time
# In I for the 73286 time
# In I for the 73287 time
# In I for the 73288 time
# In I for the 73289 time
# In I for the 73290 time
# In I for the 73291 time
# In I for the 73292 time
# In I for the 73293 time
# In I for the 73294 time
# In I for the 73295 time
# In I for the 73296 time
# In I for the 73297 time
# In I for the 73298 time
# In I for the 73299 time
# In I for the 73300 time
# In I for the 73301 time
# In I for the 73302 time
# In I for the 73303 time
# In I for the 73304 time
# In I for the 73305 time
# In I for the 73306 time
# In I for the 73307 time
# In I for the 73308 time
# In I for the 73309 time
# In I for the 73310 time
# In I for the 73311 time
# In I for the 73312 time
# In I for the 73313 time
# In I for the 73314 time
# In I for the 73315 time
# In I for the 73316 time
# In I for the 73317 time
# In I for the 73318 time
# In I for the 73319 time
# In I for the 73320 time
# In I for the 73321 time
# In I for the 73322 time
# In I for the 73323 time
# In I for the 73324 time
# In I for the 73325 time
# In I for the 73326 time
# In I for the 73327 time
# In I for the 73328 time
# In I for the 73329 time
# In I for the 73330 time
# In I for the 73331 time
# In I for the 73332 time
# In I for the 73333 time
# In I for the 73334 time
# In I for the 73335 time
# In I for the 73336 time
# In I for the 73337 time
# In I for the 73338 time
# In I for the 73339 time
# In I for the 73340 time
# In I for the 73341 time
# In I for the 73342 time
# In I for the 73343 time
# In I for the 73344 time
# In I for the 73345 time
# In I for the 73346 time
# In I for the 73347 time
# In I for the 73348 time
# In I for the 73349 time
# In I for the 73350 time
# In I for the 73351 time
# In I for the 73352 time
# In I for the 73353 time
# In I for the 73354 time
# In I for the 73355 time
# In I for the 73356 time
# In I for the 73357 time
# In I for the 73358 time
# In I for the 73359 time
# In I for the 73360 time
# In I for the 73361 time
# In I for the 73362 time
# In I for the 73363 time
# In I for the 73364 time
# In I for the 73365 time
# In I for the 73366 time
# In I for the 73367 time
# In I for the 73368 time
# In I for the 73369 time
# In I for the 73370 time
# In I for the 73371 time
# In I for the 73372 time
# In I for the 73373 time
# In I for the 73374 time
# In I for the 73375 time
# In I for the 73376 time
# In I for the 73377 time
# In I for the 73378 time
# In I for the 73379 time
# In I for the 73380 time
# In I for the 73381 time
# In I for the 73382 time
# In I for the 73383 time
# In I for the 73384 time
# In I for the 73385 time
# In I for the 73386 time
# In I for the 73387 time
# In I for the 73388 time
# In I for the 73389 time
# In I for the 73390 time
# In I for the 73391 time
# In I for the 73392 time
# In I for the 73393 time
# In I for the 73394 time
# In I for the 73395 time
# In I for the 73396 time
# In I for the 73397 time
# In I for the 73398 time
# In I for the 73399 time
# In I for the 73400 time
# In I for the 73401 time
# In I for the 73402 time
# In I for the 73403 time
# In I for the 73404 time
# In I for the 73405 time
# In I for the 73406 time
# In I for the 73407 time
# In I for the 73408 time
# In I for the 73409 time
# In I for the 73410 time
# In I for the 73411 time
# In I for the 73412 time
# In I for the 73413 time
# In I for the 73414 time
# In I for the 73415 time
# In I for the 73416 time
# In I for the 73417 time
# In I for the 73418 time
# In I for the 73419 time
# In I for the 73420 time
# In I for the 73421 time
# In I for the 73422 time
# In I for the 73423 time
# In I for the 73424 time
# In I for the 73425 time
# In I for the 73426 time
# In I for the 73427 time
# In I for the 73428 time
# In I for the 73429 time
# In I for the 73430 time
# In I for the 73431 time
# In I for the 73432 time
# In I for the 73433 time
# In I for the 73434 time
# In I for the 73435 time
# In I for the 73436 time
# In I for the 73437 time
# In I for the 73438 time
# In I for the 73439 time
# In I for the 73440 time
# In I for the 73441 time
# In I for the 73442 time
# In I for the 73443 time
# In I for the 73444 time
# In I for the 73445 time
# In I for the 73446 time
# In I for the 73447 time
# In I for the 73448 time
# In I for the 73449 time
# In I for the 73450 time
# In I for the 73451 time
# In I for the 73452 time
# In I for the 73453 time
# In I for the 73454 time
# In I for the 73455 time
# In I for the 73456 time
# In I for the 73457 time
# In I for the 73458 time
# In I for the 73459 time
# In I for the 73460 time
# In I for the 73461 time
# In I for the 73462 time
# In I for the 73463 time
# In I for the 73464 time
# In I for the 73465 time
# In I for the 73466 time
# In I for the 73467 time
# In I for the 73468 time
# In I for the 73469 time
# In I for the 73470 time
# In I for the 73471 time
# In I for the 73472 time
# In I for the 73473 time
# In I for the 73474 time
# In I for the 73475 time
# In I for the 73476 time
# In I for the 73477 time
# In I for the 73478 time
# In I for the 73479 time
# In I for the 73480 time
# In I for the 73481 time
# In I for the 73482 time
# In I for the 73483 time
# In I for the 73484 time
# In I for the 73485 time
# In I for the 73486 time
# In I for the 73487 time
# In I for the 73488 time
# In I for the 73489 time
# In I for the 73490 time
# In I for the 73491 time
# In I for the 73492 time
# In I for the 73493 time
# In I for the 73494 time
# In I for the 73495 time
# In I for the 73496 time
# In I for the 73497 time
# In I for the 73498 time
# In I for the 73499 time
# In I for the 73500 time
# In I for the 73501 time
# In I for the 73502 time
# In I for the 73503 time
# In I for the 73504 time
# In I for the 73505 time
# In I for the 73506 time
# In I for the 73507 time
# In I for the 73508 time
# In I for the 73509 time
# In I for the 73510 time
# In I for the 73511 time
# In I for the 73512 time
# In I for the 73513 time
# In I for the 73514 time
# In I for the 73515 time
# In I for the 73516 time
# In I for the 73517 time
# In I for the 73518 time
# In I for the 73519 time
# In I for the 73520 time
# In I for the 73521 time
# In I for the 73522 time
# In I for the 73523 time
# In I for the 73524 time
# In I for the 73525 time
# In I for the 73526 time
# In I for the 73527 time
# In I for the 73528 time
# In I for the 73529 time
# In I for the 73530 time
# In I for the 73531 time
# In I for the 73532 time
# In I for the 73533 time
# In I for the 73534 time
# In I for the 73535 time
# In I for the 73536 time
# In I for the 73537 time
# In I for the 73538 time
# In I for the 73539 time
# In I for the 73540 time
# In I for the 73541 time
# In I for the 73542 time
# In I for the 73543 time
# In I for the 73544 time
# In I for the 73545 time
# In I for the 73546 time
# In I for the 73547 time
# In I for the 73548 time
# In I for the 73549 time
# In I for the 73550 time
# In I for the 73551 time
# In I for the 73552 time
# In I for the 73553 time
# In I for the 73554 time
# In I for the 73555 time
# In I for the 73556 time
# In I for the 73557 time
# In I for the 73558 time
# In I for the 73559 time
# In I for the 73560 time
# In I for the 73561 time
# In I for the 73562 time
# In I for the 73563 time
# In I for the 73564 time
# In I for the 73565 time
# In I for the 73566 time
# In I for the 73567 time
# In I for the 73568 time
# In I for the 73569 time
# In I for the 73570 time
# In I for the 73571 time
# In I for the 73572 time
# In I for the 73573 time
# In I for the 73574 time
# In I for the 73575 time
# In I for the 73576 time
# In I for the 73577 time
# In I for the 73578 time
# In I for the 73579 time
# In I for the 73580 time
# In I for the 73581 time
# In I for the 73582 time
# In I for the 73583 time
# In I for the 73584 time
# In I for the 73585 time
# In I for the 73586 time
# In I for the 73587 time
# In I for the 73588 time
# In I for the 73589 time
# In I for the 73590 time
# In I for the 73591 time
# In I for the 73592 time
# In I for the 73593 time
# In I for the 73594 time
# In I for the 73595 time
# In I for the 73596 time
# In I for the 73597 time
# In I for the 73598 time
# In I for the 73599 time
# In I for the 73600 time
# In I for the 73601 time
# In I for the 73602 time
# In I for the 73603 time
# In I for the 73604 time
# In I for the 73605 time
# In I for the 73606 time
# In I for the 73607 time
# In I for the 73608 time
# In I for the 73609 time
# In I for the 73610 time
# In I for the 73611 time
# In I for the 73612 time
# In I for the 73613 time
# In I for the 73614 time
# In I for the 73615 time
# In I for the 73616 time
# In I for the 73617 time
# In I for the 73618 time
# In I for the 73619 time
# In I for the 73620 time
# In I for the 73621 time
# In I for the 73622 time
# In I for the 73623 time
# In I for the 73624 time
# In I for the 73625 time
# In I for the 73626 time
# In I for the 73627 time
# In I for the 73628 time
# In I for the 73629 time
# In I for the 73630 time
# In I for the 73631 time
# In I for the 73632 time
# In I for the 73633 time
# In I for the 73634 time
# In I for the 73635 time
# In I for the 73636 time
# In I for the 73637 time
# In I for the 73638 time
# In I for the 73639 time
# In I for the 73640 time
# In I for the 73641 time
# In I for the 73642 time
# In I for the 73643 time
# In I for the 73644 time
# In I for the 73645 time
# In I for the 73646 time
# In I for the 73647 time
# In I for the 73648 time
# In I for the 73649 time
# In I for the 73650 time
# In I for the 73651 time
# In I for the 73652 time
# In I for the 73653 time
# In I for the 73654 time
# In I for the 73655 time
# In I for the 73656 time
# In I for the 73657 time
# In I for the 73658 time
# In I for the 73659 time
# In I for the 73660 time
# In I for the 73661 time
# In I for the 73662 time
# In I for the 73663 time
# In I for the 73664 time
# In I for the 73665 time
# In I for the 73666 time
# In I for the 73667 time
# In I for the 73668 time
# In I for the 73669 time
# In I for the 73670 time
# In I for the 73671 time
# In I for the 73672 time
# In I for the 73673 time
# In I for the 73674 time
# In I for the 73675 time
# In I for the 73676 time
# In I for the 73677 time
# In I for the 73678 time
# In I for the 73679 time
# In I for the 73680 time
# In I for the 73681 time
# In I for the 73682 time
# In I for the 73683 time
# In I for the 73684 time
# In I for the 73685 time
# In I for the 73686 time
# In I for the 73687 time
# In I for the 73688 time
# In I for the 73689 time
# In I for the 73690 time
# In I for the 73691 time
# In I for the 73692 time
# In I for the 73693 time
# In I for the 73694 time
# In I for the 73695 time
# In I for the 73696 time
# In I for the 73697 time
# In I for the 73698 time
# In I for the 73699 time
# In I for the 73700 time
# In I for the 73701 time
# In I for the 73702 time
# In I for the 73703 time
# In I for the 73704 time
# In I for the 73705 time
# In I for the 73706 time
# In I for the 73707 time
# In I for the 73708 time
# In I for the 73709 time
# In I for the 73710 time
# In I for the 73711 time
# In I for the 73712 time
# In I for the 73713 time
# In I for the 73714 time
# In I for the 73715 time
# In I for the 73716 time
# In I for the 73717 time
# In I for the 73718 time
# In I for the 73719 time
# In I for the 73720 time
# In I for the 73721 time
# In I for the 73722 time
# In I for the 73723 time
# In I for the 73724 time
# In I for the 73725 time
# In I for the 73726 time
# In I for the 73727 time
# In I for the 73728 time
# In I for the 73729 time
# In I for the 73730 time
# In I for the 73731 time
# In I for the 73732 time
# In I for the 73733 time
# In I for the 73734 time
# In I for the 73735 time
# In I for the 73736 time
# In I for the 73737 time
# In I for the 73738 time
# In I for the 73739 time
# In I for the 73740 time
# In I for the 73741 time
# In I for the 73742 time
# In I for the 73743 time
# In I for the 73744 time
# In I for the 73745 time
# In I for the 73746 time
# In I for the 73747 time
# In I for the 73748 time
# In I for the 73749 time
# In I for the 73750 time
# In I for the 73751 time
# In I for the 73752 time
# In I for the 73753 time
# In I for the 73754 time
# In I for the 73755 time
# In I for the 73756 time
# In I for the 73757 time
# In I for the 73758 time
# In I for the 73759 time
# In I for the 73760 time
# In I for the 73761 time
# In I for the 73762 time
# In I for the 73763 time
# In I for the 73764 time
# In I for the 73765 time
# In I for the 73766 time
# In I for the 73767 time
# In I for the 73768 time
# In I for the 73769 time
# In I for the 73770 time
# In I for the 73771 time
# Vectores X and Y have been created

# %%
X
# Out:
# <73771x10 sparse matrix of type '<class 'numpy.float64'>'
# 	with 737710 stored elements in Compressed Sparse Row format>

# %%
Y
# Out:
# <73771x10 sparse matrix of type '<class 'numpy.float64'>'
# 	with 737710 stored elements in Compressed Sparse Row format>

# %%
#Function to find similar books


def give_similar(book_id,X,Y):
    
    
    book_vec = Y[book_id].T

   #selecting 10 most similar books
    scores = Y.dot(book_vec).toarray().reshape(1,-1)[0]
    top_10 = np.argsort(scores)[::-1][:10]

    books = []
    books_scores = []

    #print
    for idx in top_10:
        books.append(books_lookup.book_title.loc[books_lookup.ISBN_id == str(idx)].iloc[0])
        books_scores.append(scores[idx])
    
    similar = pd.DataFrame({'Book': books})
    pd.set_option('display.max_colwidth', -1)
    print (similar)

# %%
give_similar(45911,X,Y)
# Out:
#                                                                              Book
# 0  "Harry Potter and the Order of the Phoenix (Book 5)"
# 1  "Chicken Soup for the Woman's Soul (Chicken Soup for the Soul Series (Paper))"
# 2  "Face the Fire (Three Sisters Island Trilogy)"
# 3  "Girl in Hyacinth Blue"
# 4  "Daughter of Fortune : A Novel (Oprah's Book Club (Hardcover))"
# 5  "The Tale of the Body Thief (Vampire Chronicles (Paperback))"
# 6  "The Celestine Prophecy (Celestine Prophecy)"
# 7  "Purity in Death"
# 8  "Life's Little Instruction Book (Life's Little Instruction Books (Paperback))"
# 9  "Strange Fits of Passion: A Novel"

# %%
def recommend(USER_id, ratings_matrix, X, Y, no_of_books):
    """Recommend items for a given user given a trained model
    
        user_id (int): The id of the user we want to create recommendations for.    
        ratings_matrix (csr_matrix): Our original training data.
        X (csr_matrix): The trained user x features vectors
        Y (csr_matrix): The trained item x features vectors
        no_of_books (int): How many recommendations we want to return.
        
    Returns:
        recommendations (pandas.DataFrame): DataFrame with recommended books
    """
  
    
    user_interactions = ratings_matrix[USER_id,:].toarray()

    # Already read and rated for are set to 0
    
    user_interactions = user_interactions.reshape(-1) + 1    #Reshape to turn into 1D array
    user_interactions[user_interactions > 1] = 0

    #Calculating the recommendation
    rec_vector = X[USER_id,:].dot(Y.T).toarray()

    #Scaling.
    min_max = MinMaxScaler()
    rec_vector_scaled = min_max.fit_transform(rec_vector.reshape(-1,1))[:,0]
    recommend_vector = user_interactions*rec_vector_scaled
   
    #Top10. 
    book_index = np.argsort(recommend_vector)[::-1][:no_of_books]

    books = []
    scores = []
    
    for book in book_index:
        books.append(books_lookup.book_title.loc[books_lookup.ISBN_id == str(book)].iloc[0])
        scores.append(recommend_vector[book])

    recommendations = pd.DataFrame({'Book': books, 'Score': scores})
    print(recommendations)

# %%
recommend(1156,ratings_matrix,X,Y,10)
# Out:
#                                                              Book     Score
# 0  "A Painted House"                                               1.000000
# 1  "The No. 1 Ladies' Detective Agency (Today Show Book Club #8)"  0.838920
# 2  "Snow Falling on Cedars"                                        0.829849
# 3  "The Bridges of Madison County"                                 0.795668
# 4  "The Hundred Secret Senses"                                     0.740169
# 5  "All I Really Need to Know"                                     0.703483
# 6  "Lonesome Dove"                                                 0.700446
# 7  "Harry Potter and the Sorcerer's Stone (Book 1)"                0.690732
# 8  "Tears of the Giraffe (No.1 Ladies Detective Agency)"           0.676075
# 9  "A Child Called \"It\": One Child's Courage to Survive"         0.672392

# %%
#Create a simple GUI
import tkinter as tk
from tkinter.simpledialog import askstring, askinteger
from tkinter.messagebox import showerror


def display_1():
   
    num1 = entry_1.get()
    text = merged_books_df.loc[merged_books_df['Book_Title'] == '"' + num1 + '"','ISBN_ID']
    print(text[0])
    book_id_string = text[0]
    print(book_id_string)
    give_similar(book_id_string,user_vecs,item_vecs)
    

def display_2():
    num = entry_2.get()
 
    try:
       num = int(num)
    except ValueError:
        showerror('Non-Int Error', 'Please enter an integer')
    else:
        recommend(num,ratings_matrix,user_vecs,item_vecs,10)

    

root = tk.Tk()


entry_1 = tk.Entry(root)
btn_1 = tk.Button(root, text = "Submit Book title", command = display_1)

entry_2 = tk.Entry(root)
btn_2 = tk.Button(root, text = "Submit User title", command = display_2)


entry_1.grid(row = 0, column = 0)
btn_1.grid(row = 1, column = 0)
entry_2.grid(row = 0, column = 1)
btn_2.grid(row = 1, column = 1)

#entry_1_string = str(entry_1)
#entry_1_string = '"' + entry_1_string + '"'
#text = merged_books_df.loc[merged_books_df['Book_Title'] == entry_1_string,'ISBN_ID']
#book_Id_entry = text.iloc[0]
#book_Id_entry

root.mainloop()
